# %%
using CSV, DataFrames

# %%
raw = CSV.read("data_to_convert_to_table2.csv",DataFrame);
data = Matrix(raw);

# %%
rho = ["0.05", "0.5", "5"];
SPs = ["3", "6", "9"]
DPs = ["10", "20", "30"];

# %%
count = 0;

df = DataFrame();

for r in rho
    for s in SPs
        for d in DPs
            count += 1
            #first 3 terms
            term1 = ""
            if count in [1, 10, 19]
                term1 *= "$r & $s \$\\quad\$       $d && "
            elseif count in [4, 7, 13, 16, 22, 25]
                term1 *= "      & $s \$\\quad\$       $d && "
            else
                term1 *= "      &    \$\\quad\\quad\$ $d && "
            end
            print(term1)
            ccount = 0
            temp = [];
            for i=1:11
                ccount += 1
                if '%' ∉ data[count,i]
                    if ccount < 11
                        print(data[count,i], " &")
                    else
                        print(data[count,i], " ")
                    end
                else
                    if ccount < 11
                        print(data[count,i][1:end-1]*"\\%", " &")
                    else
                        print(data[count,i][1:end-1]*"\\%", " ")
                    end                    
                end
                if ccount in [4, 7]
                    print("& ")
                else
                    print("")
                end
            end
            print(" \\\\")
            println(" ")
        end
    end
    print(" \\\\")
    println(" ")
end
# Out:
# 0.05 & 3 $\quad$       10 && 674.4 &77.3 &14.1 &3.3\% && 4115.6 &84.1 &530.4\% && 4810.1 &594.1 &0.2 &636.7\%  \\
#       &    $\quad\quad$ 20 && 1353.2 &147.8 &21.8 &3.3\% && 7565.4 &162.5 &477.4\% && 9210.6 &1275.2 &0.3 &602.9\%  \\
#       &    $\quad\quad$ 30 && 2012.5 &219.2 &28.4 &3.3\% && 12128.6 &233.5 &522.5\% && 14336.6 &1789.6 &0.3 &635.9\%  \\
#       & 6 $\quad$       10 && 651.4 &74.2 &20.4 &2.1\% && 4094.2 &74.1 &541.9\% && 4838.7 &593.1 &0.4 &658.6\%  \\
#       &    $\quad\quad$ 20 && 1318.7 &143.8 &33.3 &2.5\% && 7594.6 &155.7 &490.6\% && 9263.6 &1273.7 &0.5 &620.4\%  \\
#       &    $\quad\quad$ 30 && 1973.8 &215.2 &45.3 &2.9\% && 12160.9 &218.1 &533.7\% && 14430.5 &1787.1 &0.7 &652.0\%  \\
#       & 9 $\quad$       10 && 651.4 &74.2 &28.6 &1.9\% && 4138.2 &81.6 &547.4\% && 4843.0 &593.9 &0.4 &657.6\%  \\
#       &    $\quad\quad$ 20 && 1318.6 &143.8 &46.9 &2.4\% && 7628.6 &162.8 &492.2\% && 9265.1 &1274.2 &0.7 &619.2\%  \\
#       &    $\quad\quad$ 30 && 1973.7 &215.2 &64.4 &2.7\% && 12250.1 &233.2 &537.4\% && 14444.2 &1788.5 &0.7 &651.5\%  \\
#  \\
# 0.5 & 3 $\quad$       10 && 1748.6 &209.1 &15.9 &130.6\% && 4394.2 &129.6 &479.6\% && 4932.6 &603.0 &0.2 &550.6\%  \\
#       &    $\quad\quad$ 20 && 3504.6 &399.0 &27.1 &131.1\% && 8147.3 &248.8 &437.3\% && 9450.7 &1287.2 &0.4 &523.3\%  \\
#       &    $\quad\quad$ 30 && 5206.7 &590.5 &34.3 &133.9\% && 12884.8 &353.4 &478.8\% && 14665.4 &1806.3 &0.4 &558.8\%  \\
#       & 6 $\quad$       10 && 1688.8 &200.7 &23.7 &128.5\% && 4339.8 &117.8 &487.2\% && 4933.2 &601.7 &0.4 &567.5\%  \\
#       &    $\quad\quad$ 20 && 3414.6 &388.2 &40.3 &132.9\% && 8109.5 &239.6 &453.1\% && 9443.3 &1284.8 &0.7 &544.1\%  \\
#       &    $\quad\quad$ 30 && 5105.7 &579.7 &56.0 &136.6\% && 12841.8 &332.8 &495.1\% && 14680.7 &1801.7 &1.0 &580.4\%  \\
#       & 9 $\quad$       10 && 1688.7 &200.7 &34.5 &124.2\% && 4394.3 &127.3 &483.4\% && 4945.0 &601.9 &0.5 &556.5\%  \\
#       &    $\quad\quad$ 20 && 3414.4 &388.1 &58.8 &129.7\% && 8152.9 &247.0 &448.5\% && 9462.5 &1285.5 &1.0 &536.6\%  \\
#       &    $\quad\quad$ 30 && 5105.5 &579.6 &80.9 &134.1\% && 12923.5 &348.2 &492.6\% && 14700.7 &1803.6 &1.3 &574.1\%  \\
#  \\
# 5 & 3 $\quad$       10 && 5978.7 &666.9 &21.2 &230.1\% && 5711.9 &492.2 &215.4\% && 5978.7 &666.9 &0.3 &230.1\%  \\
#       &    $\quad\quad$ 20 && 11475.1 &1388.5 &33.3 &221.4\% && 11013.0 &991.9 &208.5\% && 11475.1 &1388.5 &0.4 &221.4\%  \\
#       &    $\quad\quad$ 30 && 17331.8 &2075.5 &46.7 &246.9\% && 16443.8 &1400.5 &229.1\% && 17331.8 &2075.5 &0.6 &246.9\%  \\
#       & 6 $\quad$       10 && 5796.9 &668.5 &34.6 &245.4\% && 5499.2 &476.7 &227.7\% && 5796.9 &668.5 &0.4 &245.4\%  \\
#       &    $\quad\quad$ 20 && 11113.5 &1370.9 &63.2 &249.6\% && 10589.4 &947.0 &233.1\% && 11113.5 &1370.9 &0.7 &249.6\%  \\
#       &    $\quad\quad$ 30 && 16845.6 &2043.5 &90.1 &278.4\% && 15890.5 &1342.7 &256.9\% && 16845.6 &2043.5 &1.1 &278.4\%  \\
#       & 9 $\quad$       10 && 5855.0 &675.8 &47.4 &229.2\% && 5533.3 &481.0 &211.1\% && 5855.0 &675.8 &0.5 &229.2\%  \\
#       &    $\quad\quad$ 20 && 11196.3 &1380.2 &89.6 &237.5\% && 10633.4 &953.9 &220.5\% && 11196.3 &1380.2 &1.0 &237.5\%  \\
#       &    $\quad\quad$ 30 && 16878.6 &2085.7 &127.1 &267.7\% && 15910.2 &1378.0 &246.6\% && 16878.6 &2085.7 &1.2 &267.7\%  \\
#  \\
