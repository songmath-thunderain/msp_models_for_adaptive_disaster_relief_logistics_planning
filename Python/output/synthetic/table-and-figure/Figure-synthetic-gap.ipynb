# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def createFigure(inputname, outputname):
    # Load the data from the CSV file
    #file_path = 'for-Figure-synthetic-gap-1.csv'
    data = pd.read_csv(inputname)

    # Calculate the average percentage gap for each value of nu
    average_gaps = data.groupby('nu')[['FA', 'WS', 'r-2SSP', 's-2SSP']].mean()
    print(average_gaps)
    # Plot the results using a bar chart
    average_gaps.plot(kind='bar', figsize=(10, 6))
    plt.title(r"Average Percentage Gap for Different Values of $\nu$")
    plt.xlabel(r"$\nu$")
    plt.ylabel('Average Percentage Gap (%)')
    plt.xticks(rotation=0)
    plt.legend(title='Approach',loc="upper left")
    plt.grid(axis='y')
    # Save the figure to a file
    #plt.savefig('average_percentage_gap1.png')
    plt.savefig(outputname)
    plt.show()

# %%
createFigure('for-Figure-synthetic-gap-1.csv','average_percentage_gap1.png')
createFigure('for-Figure-synthetic-gap-2.csv','average_percentage_gap2.png')
createFigure('for-Figure-synthetic-gap-3.csv','average_percentage_gap3.png')
createFigure('for-Figure-synthetic-gap-4.csv','average_percentage_gap4.png')
# Out:
#              FA          WS      r-2SSP      s-2SSP
# nu
# 0.0  106.888889  106.333333  106.333333  639.222222
# 0.5  238.000000  303.888889  440.666667  534.777778
# 5.0  194.333333  205.111111  202.555556  205.111111
#              FA          WS      r-2SSP      s-2SSP
# nu
# 0.0  193.777778  369.111111  225.222222  653.666667
# 0.5  276.444444  522.111111  469.555556  534.888889
# 5.0  234.333333  241.555556  243.666667  241.555556
#             FA          WS      r-2SSP      s-2SSP
# nu
# 2   151.888889  200.222222  225.444444  599.111111
# 5   170.777778  233.111111  204.888889  494.888889
# 10  165.888889  181.111111  173.666667  383.333333
#             FA          WS      r-2SSP      s-2SSP
# nu
# 2   151.888889  200.222222  225.444444  599.111111
# 5   170.777778  233.111111  204.888889  494.888889
# 10  165.888889  181.111111  173.666667  383.333333
