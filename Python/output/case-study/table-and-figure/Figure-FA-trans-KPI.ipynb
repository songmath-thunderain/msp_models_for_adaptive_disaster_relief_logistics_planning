# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
file_path = '../trans-SA-FA-KPI-1.xlsx'
data = pd.read_excel(file_path)
data
# Out:
#    trans   procurement       salvage     penalty
# 0   0.25  88924.074024  61510.287899  179.962381
# 1   0.50  87646.622636  60264.573801  211.699672
# 2   1.00  85104.733203  57788.213951  277.229254
# 3   2.00  80744.775875  53562.463716  411.436347
# 4   4.00  75683.053848  48747.494176  658.188835

# %%
# Extracting the data
penalty = data['trans']
procurement = data['procurement']
salvage = data['salvage']
penalty_cost = data['penalty']

# Define the width of the bars
bar_width = 0.2

# Set the position of the bars on the x-axis
r1 = np.arange(len(penalty))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plotting the data
plt.figure(figsize=(12, 6))

# Creating the bars
plt.bar(r1, procurement, color='skyblue', width=bar_width, edgecolor='grey', label='Inventory')
plt.bar(r2, salvage, color='lightgreen', width=bar_width, edgecolor='grey', label='Salvage')
plt.bar(r3, penalty_cost, color='lightcoral', width=bar_width, edgecolor='grey', label='Penalty')

# Adding labels and title
plt.xlabel('Transportation Cost Parameter', fontweight='bold')
plt.xticks([r + bar_width for r in range(len(penalty))], penalty)
plt.ylabel('Amount', fontweight='bold')
plt.title('Average Amount of Inventory, Salvage, and Demand Shortage under Different Transportation Cost Parameters', fontweight='bold')
plt.legend()

# Show plot
plt.show()
plt.savefig('FA-trans-cost-composition-1.png');

# %%
# Load the data
file_path = '../trans-SA-FA-KPI-2.xlsx'
data = pd.read_excel(file_path)
data
# Out:
#    trans   procurement       salvage     penalty
# 0   0.25  84666.358663  61150.869842  342.995681
# 1   0.50  82856.030387  59413.831379  416.285494
# 2   1.00  80743.654556  57316.646779  431.476725
# 3   2.00  76958.598795  53635.017616  534.903323
# 4   4.00  70847.511617  47786.348329  797.321214

# %%
# Extracting the data
penalty = data['trans']
procurement = data['procurement']
salvage = data['salvage']
penalty_cost = data['penalty']

# Define the width of the bars
bar_width = 0.2

# Set the position of the bars on the x-axis
r1 = np.arange(len(penalty))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Plotting the data
plt.figure(figsize=(12, 6))

# Creating the bars
plt.bar(r1, procurement, color='skyblue', width=bar_width, edgecolor='grey', label='Inventory')
plt.bar(r2, salvage, color='lightgreen', width=bar_width, edgecolor='grey', label='Salvage')
plt.bar(r3, penalty_cost, color='lightcoral', width=bar_width, edgecolor='grey', label='Penalty')

# Adding labels and title
plt.xlabel('Transportation Cost Parameter', fontweight='bold')
plt.xticks([r + bar_width for r in range(len(penalty))], penalty)
plt.ylabel('Amount', fontweight='bold')
plt.title('Average Amount of Inventory, Salvage, and Demand Shortage under Different Transportation Cost Parameters', fontweight='bold')
plt.legend()

# Show plot
plt.show()
plt.savefig('FA-trans-cost-composition-2.png');
